# %%
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)

print(keras.__version__)
# Out:
# 2.8.0
# 2.8.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Wczytaj dane treningowe i testowe
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

train_set = pd.read_csv('https://raw.githubusercontent.com/przem85/podstawy_sztucznej_inteligencji/main/Dane/adult/adult.data', sep=", ",header = None)
test_set = pd.read_csv('https://raw.githubusercontent.com/przem85/podstawy_sztucznej_inteligencji/main/Dane/adult/adult.test', sep=", ",skiprows = 1, header = None) # Make sure to skip a row for the test set

col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
              'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
             'wage_class']
train_set.columns = col_labels
test_set.columns = col_labels

train = train_set.replace('?', np.nan).dropna()
test = test_set.replace('?', np.nan).dropna()

train_set.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14648\357239312.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train_set = pd.read_csv('Dane/adult/adult.data', sep=", ",header = None)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14648\357239312.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_set = pd.read_csv('Dane/adult/adult.test', sep=", ",skiprows = 1, header = None) # Make sure to skip a row for the test set
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country wage_class
# 0          2174             0              40  United-States      <=50K
# 1             0             0              13  United-States      <=50K
# 2             0             0              40  United-States      <=50K
# 3             0             0              40  United-States      <=50K
# 4             0             0              40           Cuba      <=50K

# %% [markdown]
# # Zad.
# Zróbmy szybki preprocesing

# %%
dataset = pd.concat([train,test])

dataset['wage_class'] = dataset.wage_class.replace({'<=50K.': 0,'<=50K':0, '>50K.':1, '>50K':1})

dataset.drop(["fnlwgt"],axis=1,inplace=True)

dataset.drop(["education"],axis=1,inplace=True)

x = dataset.groupby('native_country')["wage_class"].mean()

d = dict(pd.cut(x[x.index!=" United-States"],5,labels=range(5)))

dataset['native_country'] = dataset['native_country'].replace(d)

dataset = pd.get_dummies(dataset,drop_first=True)

train = dataset.iloc[:train.shape[0]]
test = dataset.iloc[train.shape[0]:]

X_train = train.drop("wage_class",axis=1)
y_train = train.wage_class

X_test = test.drop("wage_class",axis=1)
y_test = test.wage_class

# %%
from keras.callbacks import ModelCheckpoint

# %%
from keras.models import Sequential
from keras.layers import Dense

from keras.callbacks import History

history = History()
model = Sequential()
model.add(Dense(100,activation="sigmoid",input_shape=(X_train.shape[1],)))
model.add(Dense(50,activation="sigmoid"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4200
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 10)                510
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 9,771
# Trainable params: 9,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
save_best_model = ModelCheckpoint("wagi_best.h5py",save_best_only=True)
model.compile(loss="binary_crossentropy",optimizer="Adam", metrics=["accuracy"])

# %%
save_best_model = ModelCheckpoint("wagi_best.h5py",save_best_only=True)
history = model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=32,epochs=100, callbacks=[save_best_model])
# Out:
# Epoch 1/100
# 926/943 [============================>.] - ETA: 0s - loss: 0.4485 - accuracy: 0.7872INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 3s 2ms/step - loss: 0.4475 - accuracy: 0.7875 - val_loss: 0.3831 - val_accuracy: 0.8058
# Epoch 2/100
# 943/943 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8117INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3793 - accuracy: 0.8117 - val_loss: 0.3719 - val_accuracy: 0.8100
# Epoch 3/100
# 943/943 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8128INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3732 - accuracy: 0.8128 - val_loss: 0.3713 - val_accuracy: 0.8180
# Epoch 4/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3727 - accuracy: 0.8128 - val_loss: 0.3763 - val_accuracy: 0.8173
# Epoch 5/100
# 930/943 [============================>.] - ETA: 0s - loss: 0.3732 - accuracy: 0.8111INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3729 - accuracy: 0.8113 - val_loss: 0.3668 - val_accuracy: 0.8164
# Epoch 6/100
# 918/943 [============================>.] - ETA: 0s - loss: 0.3717 - accuracy: 0.8134INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3713 - accuracy: 0.8130 - val_loss: 0.3661 - val_accuracy: 0.8159
# Epoch 7/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3705 - accuracy: 0.8125 - val_loss: 0.3963 - val_accuracy: 0.7899
# Epoch 8/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3705 - accuracy: 0.8145 - val_loss: 0.3688 - val_accuracy: 0.8113
# Epoch 9/100
# 943/943 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8161INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3691 - accuracy: 0.8161 - val_loss: 0.3641 - val_accuracy: 0.8167
# Epoch 10/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3671 - accuracy: 0.8146 - val_loss: 0.3683 - val_accuracy: 0.8152
# Epoch 11/100
# 931/943 [============================>.] - ETA: 0s - loss: 0.3684 - accuracy: 0.8140INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3686 - accuracy: 0.8140 - val_loss: 0.3636 - val_accuracy: 0.8165
# Epoch 12/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3682 - accuracy: 0.8151 - val_loss: 0.3769 - val_accuracy: 0.8128
# Epoch 13/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3657 - accuracy: 0.8166 - val_loss: 0.3654 - val_accuracy: 0.8176
# Epoch 14/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3659 - accuracy: 0.8158 - val_loss: 0.3666 - val_accuracy: 0.8180
# Epoch 15/100
# 930/943 [============================>.] - ETA: 0s - loss: 0.3647 - accuracy: 0.8163INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3649 - accuracy: 0.8163 - val_loss: 0.3624 - val_accuracy: 0.8187
# Epoch 16/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3646 - accuracy: 0.8165 - val_loss: 0.3641 - val_accuracy: 0.8195
# Epoch 17/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3646 - accuracy: 0.8175 - val_loss: 0.3636 - val_accuracy: 0.8171
# Epoch 18/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3654 - accuracy: 0.8157 - val_loss: 0.3744 - val_accuracy: 0.8127
# Epoch 19/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3667 - accuracy: 0.8163 - val_loss: 0.3778 - val_accuracy: 0.8054
# Epoch 20/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3644 - accuracy: 0.
100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3590 - accuracy: 0.8186 - val_loss: 0.3639 - val_accuracy: 0.8163
# Epoch 52/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8202 - val_loss: 0.3650 - val_accuracy: 0.8156
# Epoch 53/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8174 - val_loss: 0.3699 - val_accuracy: 0.8118
# Epoch 54/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3594 - accuracy: 0.8194 - val_loss: 0.3649 - val_accuracy: 0.8172
# Epoch 55/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8187 - val_loss: 0.3626 - val_accuracy: 0.8164
# Epoch 56/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8186 - val_loss: 0.3616 - val_accuracy: 0.8172
# Epoch 57/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8188 - val_loss: 0.3659 - val_accuracy: 0.8178
# Epoch 58/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3587 - accuracy: 0.8179 - val_loss: 0.3666 - val_accuracy: 0.8163
# Epoch 59/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3588 - accuracy: 0.8165 - val_loss: 0.3623 - val_accuracy: 0.8189
# Epoch 60/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3581 - accuracy: 0.8223 - val_loss: 0.3712 - val_accuracy: 0.8161
# Epoch 61/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3587 - accuracy: 0.8196 - val_loss: 0.3631 - val_accuracy: 0.8177
# Epoch 62/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3578 - accuracy: 0.8191 - val_loss: 0.3645 - val_accuracy: 0.8173
# Epoch 63/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3568 - accuracy: 0.8205 - val_loss: 0.3629 - val_accuracy: 0.8157
# Epoch 64/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3566 - accuracy: 0.8209 - val_loss: 0.3620 - val_accuracy: 0.8162
# Epoch 65/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3754 - accuracy: 0.8144 - val_loss: 0.3910 - val_accuracy: 0.7930
# Epoch 66/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3593 - accuracy: 0.8192 - val_loss: 0.3679 - val_accuracy: 0.7950
# Epoch 67/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3622 - accuracy: 0.8176 - val_loss: 0.3709 - val_accuracy: 0.8176
# Epoch 68/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3582 - accuracy: 0.8199 - val_loss: 0.3653 - val_accuracy: 0.8189
# Epoch 69/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3598 - accuracy: 0.8203 - val_loss: 0.3985 - val_accuracy: 0.8149
# Epoch 70/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3636 - accuracy: 0.8154 - val_loss: 0.3638 - val_accuracy: 0.8149
# Epoch 71/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3588 - accuracy: 0.8192 - val_loss: 0.3634 - val_accuracy: 0.8158
# Epoch 72/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8192 - val_loss: 0.3654 - val_accuracy: 0.8149
# Epoch 73/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3600 - accuracy: 0.8168 - val_loss: 0.3633 - val_accuracy: 0.8165
# Epoch 74/100
# 909/943 [===========================>..] - ETA: 0s - loss: 0.3575 - accuracy: 0.8197INFO:tensorflow:Assets written to: wagi_best.h5py\assets
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3583 - accuracy: 0.8200 - val_loss: 0.3541 - val_accuracy: 0.8270
# Epoch 75/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8253 - val_loss: 0.3647 - val_accuracy: 0.8170
# Epoch 76/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3579 - accuracy: 0.8182 - val_loss: 0.3656 - val_accuracy: 0.8187
# Epoch 77/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3580 - accuracy: 0.8190 - val_loss: 0.3648 - val_accuracy: 0.8167
# Epoch 78/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3572 - accuracy: 0.8189 - val_loss: 0.3641 - val_accuracy: 0.8162
# Epoch 79/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8193 - val_loss: 0.3643 - val_accuracy: 0.8165
# Epoch 80/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3605 - accuracy: 0.8182 - val_loss: 0.3682 - val_accuracy: 0.8163
# Epoch 81/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3583 - accuracy: 0.8185 - val_loss: 0.3672 - val_accuracy: 0.8197
# Epoch 82/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3569 - accuracy: 0.8191 - val_loss: 0.3668 - val_accuracy: 0.8149
# Epoch 83/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3567 - accuracy: 0.8187 - val_loss: 0.3647 - val_accuracy: 0.8155
# Epoch 84/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3565 - accuracy: 0.8184 - val_loss: 0.3624 - val_accuracy: 0.8162
# Epoch 85/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3545 - accuracy: 0.8230 - val_loss: 0.3667 - val_accuracy: 0.8125
# Epoch 86/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3596 - accuracy: 0.8182 - val_loss: 0.3630 - val_accuracy: 0.8163
# Epoch 87/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3571 - accuracy: 0.8190 - val_loss: 0.3701 - val_accuracy: 0.8098
# Epoch 88/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3562 - accuracy: 0.8199 - val_loss: 0.3688 - val_accuracy: 0.8151
# Epoch 89/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3579 - accuracy: 0.8205 - val_loss: 0.3661 - val_accuracy: 0.8138
# Epoch 90/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3589 - accuracy: 0.8158 - val_loss: 0.3683 - val_accuracy: 0.7961
# Epoch 91/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8203 - val_loss: 0.3660 - val_accuracy: 0.8147
# Epoch 92/100
# 943/943 [==============================] - 2s 2ms/step - loss: 0.3597 - accuracy: 0.8183 - val_loss: 0.3690 - val_accuracy: 0.8086
# Epoch 93/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3565 - accuracy: 0.8199 - val_loss: 0.3637 - val_accuracy: 0.8128
# Epoch 94/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3567 - accuracy: 0.8197 - val_loss: 0.3624 - val_accuracy: 0.8171
# Epoch 95/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3571 - accuracy: 0.8170 - val_loss: 0.3692 - val_accuracy: 0.8084
# Epoch 96/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3569 - accuracy: 0.8199 - val_loss: 0.4071 - val_accuracy: 0.7895
# Epoch 97/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3616 - accuracy: 0.8196 - val_loss: 0.3643 - val_accuracy: 0.8152
# Epoch 98/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3592 - accuracy: 0.8169 - val_loss: 0.3651 - val_accuracy: 0.8182
# Epoch 99/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3572 - accuracy: 0.8198 - val_loss: 0.3659 - val_accuracy: 0.8161
# Epoch 100/100
# 943/943 [==============================] - 1s 2ms/step - loss: 0.3594 - accuracy: 0.8170 - val_loss: 0.3656 - val_accuracy: 0.8159

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
model.evaluate(X_test,y_test)
# Out:
# 471/471 [==============================] - 1s 1ms/step - loss: 0.3656 - accuracy: 0.8159
# [0.36562514305114746, 0.815936267375946]

# %%
from sklearn import  metrics
metrics.accuracy_score(y_true= y_test, y_pred= np.argmax(model.predict(X_test), axis=-1) )
# Out:
# 0.7543160690571049

# %% [markdown]
# # Zad
#
# Wczytaj nauczony model

# %%
model = keras.models.load_model('wagi_best.h5py')
model.evaluate(X_test,y_test)
# Out:
# 471/471 [==============================] - 1s 979us/step - loss: 0.3541 - accuracy: 0.8270
# [0.3540857434272766, 0.8270252346992493]

# %% [markdown]
# # Zad
#
# * Naucz dowolny model na zbiorze MNIST.
# * Zapisz optymalne parametry uczenia do pliku
# * Wczytaj dane z pliku

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()

X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

from keras.utils import np_utils
# one hot encode outputs
y_train1 = np_utils.to_categorical(y_train)
y_test1 = np_utils.to_categorical(y_test)

y_valid1 = np_utils.to_categorical(y_valid)

print(y_train)

keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()

model.compile(loss="categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

history = model.fit(X_train, y_train1, epochs=30, validation_data=(X_valid, y_valid1))

model.save('mnist_model')

model_read = keras.models.load_model('mnist_model')

model_read.evaluate(X_test,y_test1)
# Out:
# [7 3 4 ... 5 6 8]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.6196 - accuracy: 0.8405 - val_loss: 0.3103 - val_accuracy: 0.9120
# Epoch 2/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2953 - accuracy: 0.9151 - val_loss: 0.2473 - val_accuracy: 0.9304
# Epoch 3/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2430 - accuracy: 0.9302 - val_loss: 0.2060 - val_accuracy: 0.9426
# Epoch 4/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2075 - accuracy: 0.9406 - val_loss: 0.1823 - val_accuracy: 0.9494
# Epoch 5/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1811 - accuracy: 0.9485 - val_loss: 0.1645 - val_accuracy: 0.9536
# Epoch 6/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1603 - accuracy: 0.9543 - val_loss: 0.1483 - val_accuracy: 0.9602
# Epoch 7/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1431 - accuracy: 0.9598 - val_loss: 0.1367 - val_accuracy: 0.9634
# Epoch 8/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1291 - accuracy: 0.9633 - val_loss: 0.1295 - val_accuracy: 0.9636
# Epoch 9/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1174 - accuracy: 0.9674 - val_loss: 0.1183 - val_accuracy: 0.9672
# Epoch 10/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1077 - accuracy: 0.9696 - val_loss: 0.1090 - val_accuracy: 0.9692
# Epoch 11/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0987 - accuracy: 0.9720 - val_loss: 0.1050 - val_accuracy: 0.9696
# Epoch 12/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0911 - accuracy: 0.9744 - val_loss: 0.1004 - val_accuracy: 0.9710
# Epoch 13/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0843 - accuracy: 0.9762 - val_loss: 0.0948 - val_accuracy: 0.9726
# Epoch 14/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0781 - accuracy: 0.9781 - val_loss: 0.0920 - val_accuracy: 0.9738
# Epoch 15/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0726 - accuracy: 0.9796 - val_loss: 0.0877 - val_accuracy: 0.9726
# Epoch 16/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0677 - accuracy: 0.9806 - val_loss: 0.0860 - val_accuracy: 0.9740
# Epoch 17/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0632 - accuracy: 0.9822 - val_loss: 0.0835 - val_accuracy: 0.9754
# Epoch 18/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0592 - accuracy: 0.9837 - val_loss: 0.0799 - val_accuracy: 0.9766
# Epoch 19/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0555 - accuracy: 0.9850 - val_loss: 0.0782 - val_accuracy: 0.9768
# Epoch 20/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0519 - accuracy: 0.9860 - val_loss: 0.0775 - val_accuracy: 0.9764
# Epoch 21/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0488 - accuracy: 0.9869 - val_loss: 0.0736 - val_accuracy: 0.9784
# Epoch 22/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0458 - accuracy: 0.9878 - val_loss: 0.0744 - val_accuracy: 0.9780
# Epoch 23/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0431 - accuracy: 0.9884 - val_loss: 0.0756 - val_accuracy: 0.9770
# Epoch 24/30
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0404 - accuracy: 0.9894 - val_loss: 0.0729 - val_accuracy: 0.9774
# Epoch 25/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0383 - accuracy: 0.9900 - val_loss: 0.0708 - val_accuracy: 0.9792
# Epoch 26/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0360 - accuracy: 0.9910 - val_loss: 0.0680 - val_accuracy: 0.9796
# Epoch 27/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0340 - accuracy: 0.9916 - val_loss: 0.0672 - val_accuracy: 0.9806
# Epoch 28/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0321 - accuracy: 0.9921 - val_loss: 0.0692 - val_accuracy: 0.9804
# Epoch 29/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0300 - accuracy: 0.9932 - val_loss: 0.0676 - val_accuracy: 0.9792
# Epoch 30/30
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.0285 - accuracy: 0.9935 - val_loss: 0.0673 - val_accuracy: 0.9796
# INFO:tensorflow:Assets written to: mnist_model\assets
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0688 - accuracy: 0.9799
# [0.06884098052978516, 0.9799000024795532]
